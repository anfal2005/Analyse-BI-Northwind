# %%
import pandas as pd


file_path = '..\\cleaned files\\dbo.faitcommande2.xlsx'
df1 = pd.read_excel(file_path)


print(df1.head())


print(df1.info())
print(df1.describe())
# Out:
#    order_id customer_id  employee_id     ship_address ship_country  \
# 0        30          27            9  789 27th Street          USA
# 1        31           4            3   123 4th Street          USA
# 2        32          12            4  123 12th Street          USA
# 3        33           8            6   123 8th Street          USA
# 4        34           4            9   123 4th Street          USA
#
#    order_status
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 878 entries, 0 to 877
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_id      878 non-null    int64
#  1   customer_id   878 non-null    object
#  2   employee_id   878 non-null    int64
#  3   ship_address  878 non-null    object
#  4   ship_country  878 non-null    object
#  5   order_status  878 non-null    int64
# ...
