# %%
import pandas as pd


file_path = '..\\cleaned files\\dbo.client.xlsx'
df1 = pd.read_excel(file_path)


print(df1.head())


print(df1.info())
print(df1.describe())
# Out:
#   customerid                  fullname         address country    company
# 0          1               Anna Bedecs  123 1st Street     USA  Company A
# 1          2  Antonio Gratacos Solsona  123 2nd Street     USA  Company B
# 2          3               Thomas Axen  123 3rd Street     USA  Company C
# 3          4             Christina Lee  123 4th Street     USA  Company D
# 4          5          Martin O’Donnell  123 5th Street     USA  Company E
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerid  120 non-null    object
#  1   fullname    120 non-null    object
#  2   address     120 non-null    object
#  3   country     120 non-null    object
#  4   company     120 non-null    object
# dtypes: object(5)
# memory usage: 4.8+ KB
# None
#         customerid     fullname         address country    company
# ...
