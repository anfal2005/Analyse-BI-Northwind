# %%
import pandas as pd


file_path = '..\\cleaned files\\dbo.employee.xlsx'
df1 = pd.read_excel(file_path)


print(df1.head())


print(df1.info())
print(df1.describe())
# Out:
#    employeeid firstname   lastname         address country     homenumber  \
# 0           1     Nancy  Freehafer  123 1st Avenue     USA  (123)555-0102
# 1           2    Andrew    Cencini  123 2nd Avenue     USA  (123)555-0102
# 2           3       Jan      Kotas  123 3rd Avenue     USA  (123)555-0102
# 3           4    Mariya  Sergienko  123 4th Avenue     USA  (123)555-0102
# 4           5    Steven     Thorpe  123 5th Avenue     USA  (123)555-0102
#
#                      job region
# 0   Sales Representative     WA
# 1  Vice President, Sales     WA
# 2   Sales Representative     WA
# 3   Sales Representative     WA
# 4          Sales Manager     WA
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   employeeid  18 non-null     int64
#  1   firstname   18 non-null     object
#  2   lastname    18 non-null     object
# ...
